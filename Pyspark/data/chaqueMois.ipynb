# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import year, month, countDistinct, lag, col, sum, when
from pyspark.sql.window import Window

# create a SparkSession
spark = SparkSession.builder.appName("myApp").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://65e6bc715941:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>myApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# read the CSV file into a DataFrame
df = spark.read.csv("../pret", header=True, inferSchema=True)

# %%
# filter the DataFrame to only include new clients (i.e., those who did not appear in any previous month)
windowSpec = Window.partitionBy("code_agent", "code_client").orderBy("date_de_deboursement")
df_new_clients = df.withColumn("prev_code_client", lag("code_client").over(windowSpec)) \
                  .withColumn("is_new_client", when(col("prev_code_client").isNull(), 1).otherwise(0)) \
                  .filter(col("is_new_client") == 1) \
                  .drop("prev_code_client", "is_new_client")

# group by code_agent and year/month and count distinct code_client
num_clients_df = df_new_clients.groupBy("code_agent", year("date_de_deboursement").alias("year"), month("date_de_deboursement").alias("month")).agg(countDistinct("code_client").alias("num_new_clients"))

# add a column with the previous month's number of clients for each code_agent
windowSpec = Window.partitionBy("code_agent").orderBy("year", "month")
lagged_df = num_clients_df.withColumn("prev_num_new_clients", lag("num_new_clients").over(windowSpec))

# calculate the percentage of new clients relative to the total number of clients for each code_agent
final_df = lagged_df.withColumn("num_all_clients", sum("num_new_clients").over(windowSpec)) \
                   .withColumn("pct_new_clients", col("num_new_clients") / col("num_all_clients") * 100)

# show the final DataFrame
final_df.show(10)
# Out:
# [Stage 14:==============>                                           (1 + 3) / 4]
# +----------+----+-----+---------------+--------------------+---------------+------------------+
# |code_agent|year|month|num_new_clients|prev_num_new_clients|num_all_clients|   pct_new_clients|
# +----------+----+-----+---------------+--------------------+---------------+------------------+
# |      2001|2019|    3|              2|                null|              2|             100.0|
# |      2001|2019|    5|              2|                   2|              4|              50.0|
# |      2002|2019|    2|             19|                null|             19|             100.0|
# |      2002|2019|    3|             15|                  19|             34| 44.11764705882353|
# |      2002|2019|    4|             31|                  15|             65| 47.69230769230769|
# |      2002|2019|    5|             32|                  31|             97| 32.98969072164948|
# |      2002|2019|    6|             24|                  32|            121|19.834710743801654|
# |      2002|2019|    7|             39|                  24|            160|            24.375|
# |      2002|2019|    8|             17|                  39|            177|   9.6045197740113|
# |      2002|2019|    9|             65|                  17|            242|26.859504132231404|
# +----------+----+-----+---------------+--------------------+---------------+------------------+
# only showing top 10 rows

# %%
# Group by code_agent and calculate the mean percentage of all months
mean_pct_df = final_df.groupBy("code_agent").agg({"pct_new_clients": "mean"})

# Show the resulting DataFrame
mean_pct_df.tail(400)
# Out:
# [Row(code_agent=3270, avg(pct_new_clients)=9.137631915823214),
#  Row(code_agent=3272, avg(pct_new_clients)=8.938538271290975),
#  Row(code_agent=3273, avg(pct_new_clients)=8.85185122589705),
#  Row(code_agent=3274, avg(pct_new_clients)=9.374524447461322),
#  Row(code_agent=3275, avg(pct_new_clients)=9.240737963284175),
#  Row(code_agent=3276, avg(pct_new_clients)=8.252254644841436),
#  Row(code_agent=3277, avg(pct_new_clients)=9.410548179803664),
#  Row(code_agent=3278, avg(pct_new_clients)=8.55950436581708),
#  Row(code_agent=3279, avg(pct_new_clients)=9.665168453417495),
#  Row(code_agent=3281, avg(pct_new_clients)=9.30251268052417),
#  Row(code_agent=3282, avg(pct_new_clients)=9.499918855289394),
#  Row(code_agent=3286, avg(pct_new_clients)=8.575668057277179),
#  Row(code_agent=3287, avg(pct_new_clients)=9.164846685529392),
#  Row(code_agent=3288, avg(pct_new_clients)=61.11111111111111),
#  Row(code_agent=3291, avg(pct_new_clients)=8.668132405457115),
#  Row(code_agent=3292, avg(pct_new_clients)=75.0),
#  Row(code_agent=3294, avg(pct_new_clients)=16.42361061507175),
#  Row(code_agent=3295, avg(pct_new_clients)=34.09317684989312),
#  Row(code_agent=3296, avg(pct_new_clients)=8.465047319420082),
#  Row(code_agent=3298, avg(pct_new_clients)=8.550984807320036),
#  Row(code_agent=3299, avg(pct_new_clients)=8.325233924048078),
#  Row(code_agent=3301, avg(pct_new_clients)=7.832516096585585),
#  Row(code_agent=3302, avg(pct_new_clients)=7.967320257283003),
#  Row(code_agent=3303, avg(pct_new_clients)=8.986822506557884),
#  Row(code_agent=3304, avg(pct_new_clients)=8.698616824145637),
#  Row(code_agent=3305, avg(pct_new_clients)=9.065350606156086),
#  Row(code_agent=3306, avg(pct_new_clients)=8.482397604876008),
#  Row(code_agent=3307, avg(pct_new_clients)=8.702596884243405),
#  Row(code_agent=3310, avg(pct_new_clients)=8.023631098689911),
#  Row(code_agent=3311, avg(pct_new_clients)=9.041219713377226),
#  Row(code_agent=3313, avg(pct_new_clients)=8.791437529714667),
#  Row(code_agent=3314, avg(pct_new_clients)=7.905655542177048),
#  Row(code_agent=3315, avg(pct_new_clients)=8.237751724155968),
#  Row(code_agent=3318, avg(pct_new_clients)=44.47278911564626),
#  Row(code_agent=3319, avg(pct_new_clients)=8.455693201400562),
#  Row(code_agent=3320, avg(pct_new_clients)=9.776097881988257),
#  Row(code_agent=3321, avg(pct_new_clients)=9.045210595011108),
#  Row(code_agent=3322, avg(pct_new_clients)=11.247045663039824),
#  Row(code_agent=3323, avg(pct_new_clients)=9.170642904606122),
#  Row(code_agent=3326, avg(pct_new_clients)=52.08333333333333),
#  Row(code_agent=3327, avg(pct_new_clients)=9.798487368840346),
#  Row(code_agent=3328, avg(pct_new_clients)=8.842140600887905),
#  Row(code_agent=3330, avg(pct_new_clients)=8.881961859963557),
#  Row(code_agent=3331, avg(pct_new_clients)=9.575614368257305),
#  Row(code_agent=3332, avg(pct_new_clients)=9.56903608350121),
#  Row(code_agent=3333, avg(pct_new_clients)=10.79034978230362),
#  Row(code_agent=3335, avg(pct_new_clients)=8.714566213717351),
#  Row(code_agent=3336, avg(pct_new_clients)=10.159887121658635),
#  Row(code_agent=3337, avg(pct_new_clients)=8.759376796807597),
#  Row(code_agent=3338, avg(pct_new_clients)=100.0),
#  Row(code_agent=3339, avg(pct_new_clients)=8.520240895539951),
#  Row(code_agent=3341, avg(pct_new_clients)=8.484894090895194),
#  Row(code_agent=3342, avg(pct_new_clients)=10.435003541065589),
#  Row(code_agent=3343, avg(pct_new_clients)=21.655041831763764),
#  Row(code_agent=3344, avg(pct_new_clients)=9.561268450394488),
#  Row(code_agent=3345, avg(pct_new_clients)=18.202522597459367),
#  Row(code_agent=3346, avg(pct_new_clients)=9.136401166307865),
#  Row(code_agent=3348, avg(pct_new_clients)=8.791509553425465),
#  Row(code_agent=3351, avg(pct_new_clients)=9.673146106148469),
#  Row(code_agent=3352, avg(pct_new_clients)=11.699543059870633),
#  Row(code_agent=3353, avg(pct_new_clients)=11.08073561549104),
#  Row(code_agent=3354, avg(pct_new_clients)=10.08487169144148),
#  Row(code_agent=3355, avg(pct_new_clients)=8.514822298368896),
#  Row(code_agent=3356, avg(pct_new_clients)=9.684476912713855),
#  Row(code_agent=3357, avg(pct_new_clients)=10.449789605534665),
#  Row(code_agent=3358, avg(pct_new_clients)=7.975573162035366),
#  Row(code_agent=3360, avg(pct_new_clients)=9.532545333660856),
#  Row(code_agent=3361, avg(pct_new_clients)=13.808742864516134),
#  Row(code_agent=3362, avg(pct_new_clients)=13.36844198338388),
#  Row(code_agent=3363, avg(pct_new_clients)=8.78433076114157),
#  Row(code_agent=3364, avg(pct_new_clients)=8.27936366571026),
#  Row(code_agent=3365, avg(pct_new_clients)=9.254172341159528),
#  Row(code_agent=3366, avg(pct_new_clients)=100.0),
#  Row(code_agent=3367, avg(pct_new_clients)=17.340286273041936),
#  Row(code_agent=3368, avg(pct_new_clients)=8.860812576733085),
#  Row(code_agent=3369, avg(pct_new_clients)=9.253490921650663),
#  Row(code_agent=3370, avg(pct_new_clients)=9.124143959272665),
#  Row(code_agent=3371, avg(pct_new_clients)=8.300766924943444),
#  Row(code_agent=3373, avg(pct_new_clients)=8.648749283791856),
#  Row(code_agent=3374, avg(pct_new_clients)=9.089396712833086),
#  Row(code_agent=3375, avg(pct_new_clients)=10.234476665962951),
#  Row(code_agent=3376, avg(pct_new_clients)=12.418635236990019),
#  Row(code_agent=3377, avg(pct_new_clients)=17.774710018274956),
#  Row(code_agent=3378, avg(pct_new_clients)=8.546168962908931),
#  Row(code_agent=3379, avg(pct_new_clients)=9.523719618891691),
#  Row(code_agent=3380, avg(pct_new_clients)=9.416416186651551),
#  Row(code_agent=3381, avg(pct_new_clients)=11.20845550866626),
#  Row(code_agent=3382, avg(pct_new_clients)=9.348115096052712),
#  Row(code_agent=3384, avg(pct_new_clients)=9.004635826780007),
#  Row(code_agent=3385, avg(pct_new_clients)=8.972029552364253),
#  Row(code_agent=3386, avg(pct_new_clients)=8.426944318366132),
#  Row(code_agent=3388, avg(pct_new_clients)=9.747939697692825),
#  Row(code_agent=3389, avg(pct_new_clients)=14.16564988164013),
#  Row(code_agent=3391, avg(pct_new_clients)=9.596852666422604),
#  Row(code_agent=3392, avg(pct_new_clients)=8.298802037005379),
#  Row(code_agent=3393, avg(pct_new_clients)=10.624158084789823),
#  Row(code_agent=3394, avg(pct_new_clients)=11.254022441907418),
#  Row(code_agent=3395, avg(pct_new_clients)=14.009237639502595),
#  Row(code_agent=3396, avg(pct_new_clients)=8.79324890238112),
#  Row(code_agent=3398, avg(pct_new_clients)=9.020847090891287),
#  Row(code_agent=3399, avg(pct_new_clients)=8.427073380124863),
#  Row(code_agent=3400, avg(pct_new_clients)=8.348869466366088),
#  Row(code_agent=3401, avg(pct_new_clients)=18.662060439781396),
#  Row(code_agent=3402, avg(pct_new_clients)=11.381016005112684),
#  Row(code_agent=3405, avg(pct_new_clients)=10.075073783076025),
#  Row(code_agent=3407, avg(pct_new_clients)=15.334794495168888),
#  Row(code_agent=3408, avg(pct_new_clients)=9.8530508564473),
#  Row(code_agent=3410, avg(pct_new_clients)=10.999848748617739),
#  Row(code_agent=3414, avg(pct_new_clients)=8.831909361857406),
#  Row(code_agent=3415, avg(pct_new_clients)=9.105519748426442),
#  Row(code_agent=3417, avg(pct_new_clients)=9.316014987972038),
#  Row(code_agent=3418, avg(pct_new_clients)=8.756119471709304),
#  Row(code_agent=3419, avg(pct_new_clients)=9.97971460674015),
#  Row(code_agent=3420, avg(pct_new_clients)=8.176367591982356),
#  Row(code_agent=3421, avg(pct_new_clients)=8.663802612261474),
#  Row(code_agent=3422, avg(pct_new_clients)=8.151396138461566),
#  Row(code_agent=3424, avg(pct_new_clients)=10.051290569569185),
#  Row(code_agent=3425, avg(pct_new_clients)=9.956087441095612),
#  Row(code_agent=3426, avg(pct_new_clients)=9.479136319669282),
#  Row(code_agent=3427, avg(pct_new_clients)=8.95084630374771),
#  Row(code_agent=3428, avg(pct_new_clients)=9.89163592443419),
#  Row(code_agent=3429, avg(pct_new_clients)=9.642158209540082),
#  Row(code_agent=3430, avg(pct_new_clients)=10.136864542041227),
#  Row(code_agent=3431, avg(pct_new_clients)=8.52784655589378),
#  Row(code_agent=3432, avg(pct_new_clients)=9.077816301380393),
#  Row(code_agent=3433, avg(pct_new_clients)=9.018618368903525),
#  Row(code_agent=3434, avg(pct_new_clients)=10.789069296123456),
#  Row(code_agent=3435, avg(pct_new_clients)=9.184740038461104),
#  Row(code_agent=3436, avg(pct_new_clients)=9.069003079253804),
#  Row(code_agent=3437, avg(pct_new_clients)=8.242288481568481),
#  Row(code_agent=3438, avg(pct_new_clients)=8.121467301653883),
#  Row(code_agent=3440, avg(pct_new_clients)=8.256767771387155),
#  Row(code_agent=3441, avg(pct_new_clients)=10.129913246483044),
#  Row(code_agent=3442, avg(pct_new_clients)=8.368114552744485),
#  Row(code_agent=3443, avg(pct_new_clients)=8.726835817162856),
#  Row(code_agent=3444, avg(pct_new_clients)=8.854270756530271),
#  Row(code_agent=3445, avg(pct_new_clients)=8.75192643222961),
#  Row(code_agent=3447, avg(pct_new_clients)=8.321511056660619),
#  Row(code_agent=3448, avg(pct_new_clients)=8.29306027307987),
#  Row(code_agent=3449, avg(pct_new_clients)=9.77457611173835),
#  Row(code_agent=3450, avg(pct_new_clients)=8.723787496287514),
#  Row(code_agent=3451, avg(pct_new_clients)=8.906250003100102),
#  Row(code_agent=3452, avg(pct_new_clients)=9.404991511361448),
#  Row(code_agent=3453, avg(pct_new_clients)=10.250653893085186),
#  Row(code_agent=3454, avg(pct_new_clients)=8.910713822128175),
#  Row(code_agent=3455, avg(pct_new_clients)=9.222793096439762),
#  Row(code_agent=3456, avg(pct_new_clients)=9.20546493239718),
#  Row(code_agent=3458, avg(pct_new_clients)=11.643265777060053),
#  Row(code_agent=3459, avg(pct_new_clients)=10.21982395826522),
#  Row(code_agent=3460, avg(pct_new_clients)=9.773337559177895),
#  Row(code_agent=3461, avg(pct_new_clients)=10.322874539593426),
#  Row(code_agent=3462, avg(pct_new_clients)=55.83333333333333),
#  Row(code_agent=3464, avg(pct_new_clients)=9.321671680021925),
#  Row(code_agent=3465, avg(pct_new_clients)=8.891757677396843),
#  Row(code_agent=3466, avg(pct_new_clients)=100.0),
#  Row(code_agent=3468, avg(pct_new_clients)=9.750163176311545),
#  Row(code_agent=3469, avg(pct_new_clients)=10.67298725332102),
#  Row(code_agent=3470, avg(pct_new_clients)=8.898900664073663),
#  Row(code_agent=3471, avg(pct_new_clients)=9.472436940761634),
#  Row(code_agent=3473, avg(pct_new_clients)=9.068354218833257),
#  Row(code_agent=3475, avg(pct_new_clients)=9.346125205861547),
#  Row(code_agent=3476, avg(pct_new_clients)=8.740300492696008),
#  Row(code_agent=3477, avg(pct_new_clients)=9.040694326607467),
#  Row(code_agent=3478, avg(pct_new_clients)=16.125096244292113),
#  Row(code_agent=3479, avg(pct_new_clients)=9.532071729144988),
#  Row(code_agent=3480, avg(pct_new_clients)=8.92457045514507),
#  Row(code_agent=3481, avg(pct_new_clients)=9.918882034555411),
#  Row(code_agent=3482, avg(pct_new_clients)=8.414109246910359),
#  Row(code_agent=3483, avg(pct_new_clients)=9.650048755211978),
#  Row(code_agent=3484, avg(pct_new_clients)=15.926018916615758),
#  Row(code_agent=3485, avg(pct_new_clients)=8.398021750611978),
#  Row(code_agent=3487, avg(pct_new_clients)=9.765136663454182),
#  Row(code_agent=3488, avg(pct_new_clients)=8.728116746982924),
#  Row(code_agent=3489, avg(pct_new_clients)=11.21203435636326),
#  Row(code_agent=3490, avg(pct_new_clients)=10.675386995282448),
#  Row(code_agent=3491, avg(pct_new_clients)=9.433093741976192),
#  Row(code_agent=3492, avg(pct_new_clients)=9.202432363991585),
#  Row(code_agent=3493, avg(pct_new_clients)=13.3864063822907),
#  Row(code_agent=3495, avg(pct_new_clients)=14.399903614214894),
#  Row(code_agent=3496, avg(pct_new_clients)=8.461845074097113),
#  Row(code_agent=3497, avg(pct_new_clients)=9.561144368662022),
#  Row(code_agent=3498, avg(pct_new_clients)=9.5583995497357),
#  Row(code_agent=3500, avg(pct_new_clients)=8.891593023166232),
#  Row(code_agent=3501, avg(pct_new_clients)=8.484998224187148),
#  Row(code_agent=3504, avg(pct_new_clients)=11.098485815242201),
#  Row(code_agent=3505, avg(pct_new_clients)=9.035448792796338),
#  Row(code_agent=3506, avg(pct_new_clients)=9.322384798507915),
#  Row(code_agent=3507, avg(pct_new_clients)=9.498678291611215),
#  Row(code_agent=3508, avg(pct_new_clients)=8.575940420267633),
#  Row(code_agent=3509, avg(pct_new_clients)=11.43616697212681),
#  Row(code_agent=3510, avg(pct_new_clients)=9.41422590198463),
#  Row(code_agent=3511, avg(pct_new_clients)=10.257177497006229),
#  Row(code_agent=3512, avg(pct_new_clients)=9.649971948770263),
#  Row(code_agent=3513, avg(pct_new_clients)=9.603552182086643),
#  Row(code_agent=3514, avg(pct_new_clients)=9.975150232149108),
#  Row(code_agent=3515, avg(pct_new_clients)=8.660994820085044),
#  Row(code_agent=3516, avg(pct_new_clients)=9.34414693069665),
#  Row(code_agent=3518, avg(pct_new_clients)=10.04811619588985),
#  Row(code_agent=3520, avg(pct_new_clients)=10.197466507250788),
#  Row(code_agent=3521, avg(pct_new_clients)=8.321610748931867),
#  Row(code_agent=3522, avg(pct_new_clients)=8.693990564021723),
#  Row(code_agent=3523, avg(pct_new_clients)=8.822273267907892),
#  Row(code_agent=3525, avg(pct_new_clients)=9.242757533453695),
#  Row(code_agent=3526, avg(pct_new_clients)=9.316525383120052),
#  Row(code_agent=3527, avg(pct_new_clients)=15.318100430837356),
#  Row(code_agent=3528, avg(pct_new_clients)=8.838074887927574),
#  Row(code_agent=3530, avg(pct_new_clients)=9.131333432710909),
#  Row(code_agent=3531, avg(pct_new_clients)=8.621897310851477),
#  Row(code_agent=3532, avg(pct_new_clients)=8.737773823003113),
#  Row(code_agent=3533, avg(pct_new_clients)=10.316736907673151),
#  Row(code_agent=3534, avg(pct_new_clients)=15.094822419049173),
#  Row(code_agent=3537, avg(pct_new_clients)=14.725512888784431),
#  Row(code_agent=3538, avg(pct_new_clients)=8.334283235661006),
#  Row(code_agent=3539, avg(pct_new_clients)=39.97732426303855),
#  Row(code_agent=3540, avg(pct_new_clients)=8.89858984467106),
#  Row(code_agent=3541, avg(pct_new_clients)=9.70619009079177),
#  Row(code_agent=3542, avg(pct_new_clients)=9.658608655758075),
#  Row(code_agent=3544, avg(pct_new_clients)=10.427951728467063),
#  Row(code_agent=3546, avg(pct_new_clients)=9.550109341610014),
#  Row(code_agent=3547, avg(pct_new_clients)=15.372457071108352),
#  Row(code_agent=3548, avg(pct_new_clients)=9.603093177735733),
#  Row(code_agent=3549, avg(pct_new_clients)=9.627660092700477),
#  Row(code_agent=3550, avg(pct_new_clients)=100.0),
#  Row(code_agent=3551, avg(pct_new_clients)=8.72232868514021),
#  Row(code_agent=3552, avg(pct_new_clients)=9.033030389700588),
#  Row(code_agent=3554, avg(pct_new_clients)=9.659021219848176),
#  Row(code_agent=3555, avg(pct_new_clients)=11.465917190939974),
#  Row(code_agent=3556, avg(pct_new_clients)=13.653710962536818),
#  Row(code_agent=3558, avg(pct_new_clients)=9.346765408263543),
#  Row(code_agent=3559, avg(pct_new_clients)=8.429104872350187),
#  Row(code_agent=3560, avg(pct_new_clients)=7.96931297987348),
#  Row(code_agent=3561, avg(pct_new_clients)=8.39369165228269),
#  Row(code_agent=3562, avg(pct_new_clients)=12.846813813210103),
#  Row(code_agent=3563, avg(pct_new_clients)=9.418604655012368),
#  Row(code_agent=3564, avg(pct_new_clients)=18.436606640724474),
#  Row(code_agent=3565, avg(pct_new_clients)=100.0),
#  Row(code_agent=3566, avg(pct_new_clients)=8.910156197839344),
#  Row(code_agent=3567, avg(pct_new_clients)=9.87884347217095),
#  Row(code_agent=3568, avg(pct_new_clients)=9.607105214745507),
#  Row(code_agent=3569, avg(pct_new_clients)=8.879575980558108),
#  Row(code_agent=3570, avg(pct_new_clients)=9.788066668862038),
#  Row(code_agent=3571, avg(pct_new_clients)=9.324102899726858),
#  Row(code_agent=3572, avg(pct_new_clients)=9.117726849227973),
#  Row(code_agent=3573, avg(pct_new_clients)=9.470461738751059),
#  Row(code_agent=3574, avg(pct_new_clients)=8.51067599705396),
#  Row(code_agent=3575, avg(pct_new_clients)=9.798579341673468),
#  Row(code_agent=3576, avg(pct_new_clients)=10.662212579084025),
#  Row(code_agent=3577, avg(pct_new_clients)=13.690472398479107),
#  Row(code_agent=3578, avg(pct_new_clients)=9.475741313382594),
#  Row(code_agent=3579, avg(pct_new_clients)=9.011940517614478),
#  Row(code_agent=3580, avg(pct_new_clients)=14.151722861135607),
#  Row(code_agent=3581, avg(pct_new_clients)=9.149226905777784),
#  Row(code_agent=3583, avg(pct_new_clients)=10.289216912711494),
#  Row(code_agent=3584, avg(pct_new_clients)=9.81559704560468),
#  Row(code_agent=3585, avg(pct_new_clients)=8.944019603700173),
#  Row(code_agent=3586, avg(pct_new_clients)=8.986847093748088),
#  Row(code_agent=3587, avg(pct_new_clients)=10.58563788129023),
#  Row(code_agent=3589, avg(pct_new_clients)=16.426071036957975),
#  Row(code_agent=3590, avg(pct_new_clients)=10.076418982692479),
#  Row(code_agent=3591, avg(pct_new_clients)=9.64364584297608),
#  Row(code_agent=3592, avg(pct_new_clients)=11.172605971199463),
#  Row(code_agent=3593, avg(pct_new_clients)=9.90104317145368),
#  Row(code_agent=3594, avg(pct_new_clients)=8.088614774132944),
#  Row(code_agent=3595, avg(pct_new_clients)=11.805637526120918),
#  Row(code_agent=3596, avg(pct_new_clients)=9.872809149079378),
#  Row(code_agent=3597, avg(pct_new_clients)=8.504677398935819),
#  Row(code_agent=3598, avg(pct_new_clients)=7.487213568281343),
#  Row(code_agent=3599, avg(pct_new_clients)=9.674244091893888),
#  Row(code_agent=3600, avg(pct_new_clients)=13.510417192196996),
#  Row(code_agent=3601, avg(pct_new_clients)=26.090437817479017),
#  Row(code_agent=3602, avg(pct_new_clients)=8.916830264024572),
#  Row(code_agent=3603, avg(pct_new_clients)=8.323648797306603),
#  Row(code_agent=3604, avg(pct_new_clients)=8.269900476296195),
#  Row(code_agent=3605, avg(pct_new_clients)=9.778808911022471),
#  Row(code_agent=3606, avg(pct_new_clients)=9.478100135340691),
#  Row(code_agent=3607, avg(pct_new_clients)=9.356368987042556),
#  Row(code_agent=3608, avg(pct_new_clients)=11.689629247332922),
#  Row(code_agent=3610, avg(pct_new_clients)=9.22599810199409),
#  Row(code_agent=3611, avg(pct_new_clients)=8.698314880222265),
#  Row(code_agent=3612, avg(pct_new_clients)=7.73976468246523),
#  Row(code_agent=3613, avg(pct_new_clients)=8.296292944315928),
#  Row(code_agent=3614, avg(pct_new_clients)=8.319069635595644),
#  Row(code_agent=3615, avg(pct_new_clients)=9.906124107715994),
#  Row(code_agent=3616, avg(pct_new_clients)=100.0),
#  Row(code_agent=3617, avg(pct_new_clients)=8.268321964305756),
#  Row(code_agent=3618, avg(pct_new_clients)=10.903497254508505),
#  Row(code_agent=3619, avg(pct_new_clients)=10.778407106560676),
#  Row(code_agent=3620, avg(pct_new_clients)=8.27495751501072),
#  Row(code_agent=3621, avg(pct_new_clients)=9.63039678435656),
#  Row(code_agent=3622, avg(pct_new_clients)=9.854178432036552),
#  Row(code_agent=3623, avg(pct_new_clients)=8.631973934179548),
#  Row(code_agent=3624, avg(pct_new_clients)=9.391036767772468),
#  Row(code_agent=3625, avg(pct_new_clients)=9.449346422455513),
#  Row(code_agent=3626, avg(pct_new_clients)=8.422677230281334),
#  Row(code_agent=3627, avg(pct_new_clients)=9.221003048364755),
#  Row(code_agent=3628, avg(pct_new_clients)=9.227337880132072),
#  Row(code_agent=3629, avg(pct_new_clients)=31.800595238095237),
#  Row(code_agent=3630, avg(pct_new_clients)=10.131146564355566),
#  Row(code_agent=3631, avg(pct_new_clients)=10.776920673184307),
#  Row(code_agent=3632, avg(pct_new_clients)=11.17908794855386),
#  Row(code_agent=3633, avg(pct_new_clients)=10.104517786231652),
#  Row(code_agent=3635, avg(pct_new_clients)=13.13951539457749),
#  Row(code_agent=3636, avg(pct_new_clients)=10.569884290832393),
#  Row(code_agent=3637, avg(pct_new_clients)=9.038068037253431),
#  Row(code_agent=3638, avg(pct_new_clients)=9.12580187722867),
#  Row(code_agent=3639, avg(pct_new_clients)=8.83388723382522),
#  Row(code_agent=3640, avg(pct_new_clients)=11.167927981888415),
#  Row(code_agent=3641, avg(pct_new_clients)=8.956648213333459),
#  Row(code_agent=3642, avg(pct_new_clients)=10.787122621625578),
#  Row(code_agent=3643, avg(pct_new_clients)=75.0),
#  Row(code_agent=3644, avg(pct_new_clients)=9.92109299385123),
#  Row(code_agent=3645, avg(pct_new_clients)=10.598600396128758),
#  Row(code_agent=3646, avg(pct_new_clients)=9.487753049428413),
#  Row(code_agent=3647, avg(pct_new_clients)=53.19607843137255),
#  Row(code_agent=3648, avg(pct_new_clients)=10.216623071948074),
#  Row(code_agent=3649, avg(pct_new_clients)=10.600886372718907),
#  Row(code_agent=3650, avg(pct_new_clients)=8.556030948589749),
#  Row(code_agent=3651, avg(pct_new_clients)=10.732141114018022),
#  Row(code_agent=3652, avg(pct_new_clients)=8.705114539479363),
#  Row(code_agent=3653, avg(pct_new_clients)=17.38220004124399),
#  Row(code_agent=3654, avg(pct_new_clients)=9.631776679534445),
#  Row(code_agent=3655, avg(pct_new_clients)=9.75492164111739),
#  Row(code_agent=3656, avg(pct_new_clients)=9.772252611394471),
#  Row(code_agent=3657, avg(pct_new_clients)=8.439901390145584),
#  Row(code_agent=3658, avg(pct_new_clients)=8.673005892183692),
#  Row(code_agent=3659, avg(pct_new_clients)=8.9001955822086),
#  Row(code_agent=3660, avg(pct_new_clients)=8.841871500387958),
#  Row(code_agent=3661, avg(pct_new_clients)=10.101486830006284),
#  Row(code_agent=3662, avg(pct_new_clients)=8.844813017800442),
#  Row(code_agent=3663, avg(pct_new_clients)=9.436593478196658),
#  Row(code_agent=3664, avg(pct_new_clients)=8.74475978373216),
#  Row(code_agent=3665, avg(pct_new_clients)=9.380338159637702),
#  Row(code_agent=3666, avg(pct_new_clients)=52.028639125553134),
#  Row(code_agent=3667, avg(pct_new_clients)=9.141866480903856),
#  Row(code_agent=3668, avg(pct_new_clients)=20.320699537982797),
#  Row(code_agent=3669, avg(pct_new_clients)=10.453852955071447),
#  Row(code_agent=3670, avg(pct_new_clients)=9.211953223628049),
#  Row(code_agent=3671, avg(pct_new_clients)=9.23377148929528),
#  Row(code_agent=3672, avg(pct_new_clients)=10.235932733150015),
#  Row(code_agent=3673, avg(pct_new_clients)=9.651694521466833),
#  Row(code_agent=3674, avg(pct_new_clients)=9.547471669409425),
#  Row(code_agent=3675, avg(pct_new_clients)=10.52008789438483),
#  Row(code_agent=3676, avg(pct_new_clients)=10.440536362832253),
#  Row(code_agent=3677, avg(pct_new_clients)=12.875280004346122),
#  Row(code_agent=3678, avg(pct_new_clients)=10.641859460564596),
#  Row(code_agent=3679, avg(pct_new_clients)=100.0),
#  Row(code_agent=3680, avg(pct_new_clients)=13.809762362588918),
#  Row(code_agent=3682, avg(pct_new_clients)=17.848777566777105),
#  Row(code_agent=3684, avg(pct_new_clients)=16.964024149040977),
#  Row(code_agent=3687, avg(pct_new_clients)=14.851387167917398),
#  Row(code_agent=3688, avg(pct_new_clients)=16.436708676784978),
#  Row(code_agent=3690, avg(pct_new_clients)=15.604200038685928),
#  Row(code_agent=3694, avg(pct_new_clients)=13.278957628011339),
#  Row(code_agent=3695, avg(pct_new_clients)=13.214171691676164),
#  Row(code_agent=3696, avg(pct_new_clients)=10.665330754737514),
#  Row(code_agent=3697, avg(pct_new_clients)=11.615290646792971),
#  Row(code_agent=3698, avg(pct_new_clients)=9.141362073391612),
#  Row(code_agent=3699, avg(pct_new_clients)=9.34951323202931),
#  Row(code_agent=3700, avg(pct_new_clients)=17.41761734270857),
#  Row(code_agent=3701, avg(pct_new_clients)=10.430697241655842),
#  Row(code_agent=3703, avg(pct_new_clients)=9.857658881963015),
#  Row(code_agent=3704, avg(pct_new_clients)=10.222184751299787),
#  Row(code_agent=3705, avg(pct_new_clients)=10.390466679310094),
#  Row(code_agent=3706, avg(pct_new_clients)=8.849846044172281),
#  Row(code_agent=3707, avg(pct_new_clients)=15.903092134646762),
#  Row(code_agent=3708, avg(pct_new_clients)=10.627600244884976),
#  Row(code_agent=3709, avg(pct_new_clients)=11.993423234465478),
#  Row(code_agent=3710, avg(pct_new_clients)=56.666666666666664),
#  Row(code_agent=3711, avg(pct_new_clients)=9.578712694551605),
#  Row(code_agent=3712, avg(pct_new_clients)=13.630239795425458),
#  Row(code_agent=3713, avg(pct_new_clients)=9.222222793552312),
#  Row(code_agent=3714, avg(pct_new_clients)=8.178453249279306),
#  Row(code_agent=3715, avg(pct_new_clients)=10.10951448188041),
#  Row(code_agent=3716, avg(pct_new_clients)=9.54701687537218),
#  Row(code_agent=3717, avg(pct_new_clients)=10.426699687718061),
#  Row(code_agent=3718, avg(pct_new_clients)=8.70212591017812),
#  Row(code_agent=3719, avg(pct_new_clients)=21.41816452381467),
#  Row(code_agent=3720, avg(pct_new_clients)=8.354406294579862),
#  Row(code_agent=3721, avg(pct_new_clients)=9.073685939898454),
#  Row(code_agent=3722, avg(pct_new_clients)=8.466924655893582),
#  Row(code_agent=3723, avg(pct_new_clients)=9.591191273864133),
#  Row(code_agent=3724, avg(pct_new_clients)=11.23681394138132),
#  Row(code_agent=3725, avg(pct_new_clients)=40.83333333333333),
#  Row(code_agent=3726, avg(pct_new_clients)=45.666666666666664),
#  Row(code_agent=3727, avg(pct_new_clients)=15.167214861646048),
#  Row(code_agent=3728, avg(pct_new_clients)=24.04359820851417),
#  Row(code_agent=3729, avg(pct_new_clients)=10.269933253660284),
#  Row(code_agent=3730, avg(pct_new_clients)=11.578225244083189),
#  Row(code_agent=3731, avg(pct_new_clients)=10.654315759030453),
#  Row(code_agent=3732, avg(pct_new_clients)=11.987127984875574),
#  Row(code_agent=3733, avg(pct_new_clients)=8.007801433757823),
#  Row(code_agent=3734, avg(pct_new_clients)=25.829115329115332),
#  Row(code_agent=3735, avg(pct_new_clients)=75.0),
#  Row(code_agent=3736, avg(pct_new_clients)=52.08333333333333),
#  Row(code_agent=3737, avg(pct_new_clients)=29.289682539682538),
#  Row(code_agent=3738, avg(pct_new_clients)=9.726050255369012),
#  Row(code_agent=3739, avg(pct_new_clients)=61.11111111111111),
#  Row(code_agent=3741, avg(pct_new_clients)=17.504736173758232),
#  Row(code_agent=3742, avg(pct_new_clients)=10.451237660100675),
#  Row(code_agent=3743, avg(pct_new_clients)=10.74572068783698)]
